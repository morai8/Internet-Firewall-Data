# %% [markdown]
# <a href="https://colab.research.google.com/github/morai8/Internet-Firewall-Data/blob/main/Tugas_Siskamancer_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns #nampilih diagram
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://github.com/morai8/Internet-Firewall-Data/blob/1a5c10db6c8a5e67f55571d121c26f898510d1a9/log2.csv?raw=true")

# %%
df
# Out:
#        Source Port  Destination Port  NAT Source Port  NAT Destination Port  \
# 0            57222                53            54587                    53
# 1            56258              3389            56258                  3389
# 2             6881             50321            43265                 50321
# 3            50553              3389            50553                  3389
# 4            50002               443            45848                   443
# ...            ...               ...              ...                   ...
# 65527        63691                80            13237                    80
# 65528        50964                80            13485                    80
# 65529        54871               445                0                     0
# 65530        54870               445                0                     0
# 65531        54867               445                0                     0
#
# ...

# %%
sns.countplot(df, x="Action")
# Out:
# <Axes: xlabel='Action', ylabel='count'>

# %%
plt.hist(df["NAT Source Port"])
plt.show()

# %%
plt.hist(df["Bytes Sent"])
plt.show()

# %%
df.loc[[3555]]
# Out:
#       Source Port  Destination Port  NAT Source Port  NAT Destination Port  \
# 3555        55866               443            45291                   443
#
#      Action  Bytes  Bytes Sent  Bytes Received  Packets  Elapsed Time (sec)  \
# 3555  allow  53845        7300           46545       80                  31
#
#       pkts_sent  pkts_received
# 3555         38             42
